# %% [markdown]
# <a href="https://colab.research.google.com/github/limjimin0807/ABCD-A/blob/20250319/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EA%B8%B0%EC%B4%88_%EC%97%B0%EC%82%B0%EC%9E%90%EC%82%AC%EC%9A%A9%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
4/3
# Out:
# 1.3333333333333333

# %%
1/2
# Out:
# 0.5

# %%
4/2
# Out:
# 2.0

# %%
7//3
# Out:
# 2

# %%
7%3
# Out:
# 1

# %%
2**10
# Out:
# 1024

# %%
int(5/2)
# Out:
# 2

# %%
5//2
# Out:
# 2

# %%
a=1024
print(a)
# Out:
# 1024

# %%
a+=1024
a
# Out:
# 2048

# %%
a-=1024
a
# Out:
# 1024

# %%
a*=4
a
# Out:
# 4096

# %%
a/=2
a
# Out:
# 1024.0

# %%
a//=2
a
# Out:
# 512.0

# %%
a%=1022
a
# Out:
# 512.0

# %%
a**=10
a
# Out:
# 1.2379400392853803e+27

# %%
divmod(5, 2)
# Out:
# (2, 1)

# %%
puotient, remainder = divmod(5, 2)
print(puotient, remainder)
# Out:
# 2 1

# %%
i = 3
i += 3
print(i)
i -= 3
print(i)
i *= 2
print(i)
i /= 2
print(int (i))
i = 3
i %= 2
print(i)
# Out:
# 6
# 3
# 6
# 3
# 1

# %%
i = 3
i += 3
print(i)
i -= 3
print(i)
i *= 2
print(i)
i /= 2
print(int (i))
i = 3
i %= 2
print(i)
# Out:
# 6
# 3
# 6
# 3
# 1

# %%
a = 10
b = 3
print("10 == 3 =>", a == b)
print("10 != 3 =>", a != b)
print("10 > = 3 =>", a > b)
print("10 >= 3 =>", a >= b)
print("10 < 3 =>", a < b)
print("10 <= 3 =>", a <= b)
# Out:
# 10 == 3 => False
# 10 != 3 => True
# 10 > = 3 => True
# 10 >= 3 => True
# 10 < 3 => False
# 10 <= 3 => False

# %%
bin(13)
# Out:
# '0b1101'

# %%
0b1101
# Out:
# 13

# %%
int('1101' ,2)
# Out:
# 13

# %%
a = 13
b = 9
print(bin(a))
print(bin(b))
print(bin(a&b))
print(a&b)
# Out:
# 0b1101
# 0b1001
# 0b1001
# 9

# %%
a = 12
b = 8
print(bin(a))
print(bin(b))
print(bin(a^b))
print('')
print(a^b)
# Out:
# 0b1100
# 0b1000
# 0b100
#
# 4

# %%
a = 12
b = 8
print(bin(a))
print(bin(~a))
# Out:
# 0b1100
# -0b1101
