# %% [markdown]
# <a href="https://colab.research.google.com/github/limjimin0807/ABCD-A/blob/20250314/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%ED%94%84%EB%A6%B0%ED%84%B0_%ED%95%A8%EC%88%98%EC%82%AC%EC%9A%A9%EB%B2%95_20250314.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
print('hello', 'everyone')
print('hello'+'everyone')
print('hello', end= '!!!')
print('test')
# Out:
# hello
# hello everyone
# helloeveryone
# hello!!!test

# %%
a = 123
b ='hello'
print(a, b)
print(a, 456, b, 'world')
# Out:
# 123 hello
# 123 456 hello world

# %%
print('Hello Python!')
print("Nicr to meet you")
print('Hello "Python"')
print('Hello' 'Python!')
print('Hello', 'Python!')
print('Hello' + 'Python!')
# Out:
# Hello Python!
# Nicr to meet you
# Hello "Python"
# HelloPython!
# Hello Python!
# HelloPython!

# %%
print("화면에 직접 출력")
print('ab\'c')
print("doesn't")
print('does')
print('doesn\'t')
print("'string'")
print("\"string\"")
print('"string"')
# Out:
# 화면에 직접 출력
# ab'c
# doesn't
# does
# doesn't
# 'string'
# "string"
# "string"

# %%
s1 = '화면에 직접 출력'
s2 = 'ab\'c'
s3 = 'does'
print(s1)
print(s2)
print(s3)
print(s1[0])
print(s2[1])
print(s3[-1])
# Out:
# 화면에 직접 출력
# ab'c
# does
# 화
# b
# s

# %%
a = 2
b = 3.14
c = a+b
print(a)
print(b)
print(c)
print(round(c, 2))
print("%.2f" % (c))
print(a+b)
print(a,b,a+b,c)
d = 1e2
e = 1e-2
print(d)
print(e)
# Out:
# 2
# 3.14
# 5.140000000000001
# 5.14
# 5.14
# 5.140000000000001
# 2 3.14 5.140000000000001 5.140000000000001
# 100.0
# 0.01

# %%
item1 = '사과'
price1 = 1000
item2 = '바나나'
price2 = 500
print(item1, price1)
print(item2, price2)
# Out:
# 사과 1000
# 바나나 500

# %%
item1 = '사과'
price1 = 1000
item2 = '바나나'
str1 = '{0}는 {1}원입니다.'
print(str1.format(item1, price1))
print(str1.format(item2, price2))
# Out:
# 사과는 1000원입니다.
# 바나나는 500원입니다.

# %%
price1 = 1000
item2 = '바나나'
price2 = 500
str2 = '%s는 %d원입니다.'
print(str2%(item1, price1))
print(str2%(item2, price2))
# Out:
# 사과는 1000원입니다.
# 바나나는 500원입니다.
