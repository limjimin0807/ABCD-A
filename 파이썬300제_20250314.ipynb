# %% [markdown]
# <a href="https://colab.research.google.com/github/limjimin0807/ABCD-A/blob/20250314/%ED%8C%8C%EC%9D%B4%EC%8D%AC300%EC%A0%9C_20250314.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello warld")
# Out:
# Hello warld

# %%
print("Mary's cosmetice")
# Out:
# Mary's cosmetice

# %%
print('신씨가 소리질렀다. "도둑이야"')
# Out:
# 신씨가 소리질렀다. "도둑이야"

# %%
print("C:\\windows")
# Out:
# C:\windows

# %%
#\n은 줄바꿈, \t는 4칸의 공백을 의미
print("안녕하세요.\n 만나서\t\t반갑습니다.")
# Out:
# 안녕하세요.
#  만나서		반갑습니다.

# %%
print("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %%
print("naver", "kakao", "sk", "samsung", sep=';')
# Out:
# naver;kakao;sk;samsung

# %%
print("naver", "kakao", "sk", "samsung", sep='/')
# Out:
# naver/kakao/sk/samsung

# %%
print("first", end=';');print("second")
# Out:
# first;second

# %%
print(5/3)
# Out:
# 1.6666666666666667
